# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.utils import np_utils

# %%
credit_default=pd.read_csv("cleaned_cerditcard.csv")

# %%
credit_default.head()
# Out:
#    Unnamed: 0  limit_bal  age  pay_1  pay_2  pay_3  pay_4  pay_5  pay_6  \
# 0           0      20000   24      2      2      0      0      0      0
# 1           1     120000   26      0      2      0      0      0      2
# 2           2      90000   34      0      0      0      0      0      0
# 3           3      50000   37      0      0      0      0      0      0
# 4           4      50000   57      0      0      0      0      0      0
#
#    bill_amt1   ...     pay_amt3  pay_amt4  pay_amt5  pay_amt6  default  \
# 0       3913   ...            0         0         0         0        1
# 1       2682   ...         1000      1000         0      2000        1
# 2      29239   ...         1000      1000      1000      5000        0
# 3      46990   ...         1200      1100      1069      1000        0
# 4       8617   ...        10000      9000       689       679        0
#
#    grad_school  university  high_school  male  married
# ...

# %%
credit_default.shape
# Out:
# (30000, 27)

# %%
credit_default = credit_default.drop(credit_default.columns[[0]], axis=1)

# %%
credit_default.head()
# Out:
#    limit_bal  age  pay_1  pay_2  pay_3  pay_4  pay_5  pay_6  bill_amt1  \
# 0      20000   24      2      2      0      0      0      0       3913
# 1     120000   26      0      2      0      0      0      2       2682
# 2      90000   34      0      0      0      0      0      0      29239
# 3      50000   37      0      0      0      0      0      0      46990
# 4      50000   57      0      0      0      0      0      0       8617
#
#    bill_amt2   ...     pay_amt3  pay_amt4  pay_amt5  pay_amt6  default  \
# 0       3102   ...            0         0         0         0        1
# 1       1725   ...         1000      1000         0      2000        1
# 2      14027   ...         1000      1000      1000      5000        0
# 3      48233   ...         1200      1100      1069      1000        0
# 4       5670   ...        10000      9000       689       679        0
#
#    grad_school  university  high_school  male  married
# 0            0           1            0     0        1
# ...

# %%
X= credit_default.drop('default', axis=1)

# %%
X.head()
# Out:
#    limit_bal  age  pay_1  pay_2  pay_3  pay_4  pay_5  pay_6  bill_amt1  \
# 0      20000   24      2      2      0      0      0      0       3913
# 1     120000   26      0      2      0      0      0      2       2682
# 2      90000   34      0      0      0      0      0      0      29239
# 3      50000   37      0      0      0      0      0      0      46990
# 4      50000   57      0      0      0      0      0      0       8617
#
#    bill_amt2   ...     pay_amt2  pay_amt3  pay_amt4  pay_amt5  pay_amt6  \
# 0       3102   ...          689         0         0         0         0
# 1       1725   ...         1000      1000      1000         0      2000
# 2      14027   ...         1500      1000      1000      1000      5000
# 3      48233   ...         2019      1200      1100      1069      1000
# 4       5670   ...        36681     10000      9000       689       679
#
#    grad_school  university  high_school  male  married
# ...

# %%
traget_name = 'default'
y= credit_default[traget_name]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: default, dtype: int64

# %%
train_data_x, test_data_x, train_data_y, test_data_y =\
train_test_split(X,y, train_size=0.5, test_size=0.5, random_state=0)

# %%
train_data_x.head()
# Out:
#        limit_bal  age  pay_1  pay_2  pay_3  pay_4  pay_5  pay_6  bill_amt1  \
# 4943       70000   25      0      0      0      0      0      0      22935
# 29677      20000   34      0      0      0      0      0      0      16912
# 10145     400000   31      1      0      0      0      0      0       -166
# 3714       30000   41      0      0      0      0      0      0      29866
# 5862      180000   26      0      0      0      0      0      0      10874
#
#        bill_amt2   ...     pay_amt2  pay_amt3  pay_amt4  pay_amt5  pay_amt6  \
# 4943       23963   ...         1414      1100      1104      1000      1155
# 29677         -2   ...            0         0       310      9500       800
# 10145       -490   ...        30001      2128      3009      8006      1028
# 3714       30900   ...            0         0         0         0         0
# 5862        9324   ...         2000      2000      3109      5000      5520
#
# ...

# %%
train_data_y.head()
# Out:
# 4943     0
# 29677    0
# 10145    0
# 3714     0
# 5862     0
# Name: default, dtype: int64

# %%
model = Sequential()

# %%
model.add(Dense(16, input_shape=(25,), name='Input_Layer', activation='relu'))

# %%
# 16 neurons, 
# 4 features in the dataset

# %%
# Output Layer
model.add(Dense(2, name='Output_Layer', activation='softmax'))

# %%
# 3 neuron b/c we want to classify the output or flower into 3 categories.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# Input_Layer (Dense)          (None, 16)                416
# _________________________________________________________________
# Output_Layer (Dense)         (None, 2)                 34
# ...
# Total params: 450
# Trainable params: 450
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=["accuracy"])

# %%
# adam => Adaptive momentum-based optimizer-this generally works well for deep NNs
# crossentropy => mean that the output is the probability distibution
# low crossentropy mean y_actual == y_predicted.

# %%
# Start training
model.fit(train_data_x, train_data_y, epochs=50, batch_size=2, verbose=1)
# Out:
# Epoch 1/50
# 15000/15000 [==============================] - 5s 352us/step - loss: 12.4990 - acc: 0.2245
# Epoch 2/50
# 15000/15000 [==============================] - 5s 329us/step - loss: 12.4990 - acc: 0.2245
# Epoch 3/50
# 15000/15000 [==============================] - 5s 332us/step - loss: 12.4990 - acc: 0.2245
# Epoch 4/50
# 15000/15000 [==============================] - 5s 331us/step - loss: 12.4990 - acc: 0.2245
# Epoch 5/50
# 15000/15000 [==============================] - 5s 334us/step - loss: 12.4990 - acc: 0.2245
# Epoch 6/50
# 15000/15000 [==============================] - 5s 338us/step - loss: 12.4990 - acc: 0.2245
# Epoch 7/50
# 15000/15000 [==============================] - 5s 336us/step - loss: 12.4990 - acc: 0.2245
# Epoch 8/50
# 15000/15000 [==============================] - 5s 338us/step - loss: 12.4990 - acc: 0.2245
# Epoch 9/50
# 15000/15000 [==============================] - 5s 340us/step - loss: 12.4990 - acc: 0.2245
# Epoch 10/50
# ...

# %%
loss, accuracy = model.evaluate(test_data_x, test_data_y, verbose=0)

# %%
print("Loss={:.2f}".format(loss))

# %%
print("Accuracy = {:.2f}".format(accuracy))

# %%
input_dim = train_data_x.shape[1]

model = Sequential()
model.add(Dense(256, input_shape=(input_dim,), activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(1,  activation='sigmoid'))

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
              np.array(train_data_x), np.array(train_data_y),
              batch_size=25, epochs=50, verbose=1,
              validation_data=(np.array(test_data_x), np.array(test_data_y)))

# %%
score = model.evaluate(np.array(test_data_x), np.array(test_data_y), verbose=0)
print('Test Loss:', score[0])
print('Test Accuracy:', score[1])

# %%
model2 = Sequential()
model2.add(Dense(256, input_shape=(input_dim,), activation='relu', weights=model.layers[0].get_weights()))
model2.add(Dense(256, activation='relu', weights=model.layers[1].get_weights()))
model2.add(Dense(64, activation='relu', weights=model.layers[2].get_weights()))
model2.add(Dense(64, activation='relu', weights=model.layers[3].get_weights()))
model2.add(Dense(10, activation='sigmoid', weights=model.layers[4].get_weights()))

# %%
activations = model2.predict_on_batch(np.array(test_data_x))

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, perplexity=25, verbose=0, n_iter=500, random_state=1337)
samples = tsne.fit_transform(activations)

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(1,2)
fig.set_size_inches(20,10)

ax[0].scatter(*samples[test_data_y==0].T,color='b', alpha=0.5, label='default: NO')
ax[1].scatter(*samples[test_data_y==1].T,color='r', alpha=0.5, label='default: YES')

plt.tight_layout()
plt.show()
