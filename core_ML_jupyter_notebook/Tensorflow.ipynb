# %% [markdown]
# # Tensorflow

# %%
import pandas as pd

# %%
data = pd.read_csv('cleaned_cerditcard.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  limit_bal  age  pay_1  pay_2  pay_3  pay_4  pay_5  pay_6  \
# 0           0      20000   24      2      2      0      0      0      0
# 1           1     120000   26      0      2      0      0      0      2
# 2           2      90000   34      0      0      0      0      0      0
# 3           3      50000   37      0      0      0      0      0      0
# 4           4      50000   57      0      0      0      0      0      0
#
#    bill_amt1   ...     pay_amt3  pay_amt4  pay_amt5  pay_amt6  default  \
# 0       3913   ...            0         0         0         0        1
# 1       2682   ...         1000      1000         0      2000        1
# 2      29239   ...         1000      1000      1000      5000        0
# 3      46990   ...         1200      1100      1069      1000        0
# 4       8617   ...        10000      9000       689       679        0
#
#    grad_school  university  high_school  male  married
# ...
